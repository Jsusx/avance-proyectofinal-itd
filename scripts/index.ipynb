# %% [raw]
# Importamos las librerias y listamos las primeras 5 columnas

# %%
import pandas as pd
import matplotlib.pyplot as pit

data = pd.read_csv("../data/Postulantes-2022_1.csv", sep=",", encoding='unicode_escape')

# %% [raw]
# Mostramos la data que vamos a utilizar

# %%
columns = ['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'EDAD', 'SEXO', 'PRIMERA_OPCION', 'SEGUNDA_OPCION']
data[columns].head(5)
# Out:
#   DEPARTAMENTO PROVINCIA              DISTRITO  EDAD       SEXO  \
# 0       CALLAO    CALLAO                CALLAO    18  Masculino
# 1         LIMA      LIMA                  LIMA    31  Masculino
# 2         LIMA      LIMA                  LIMA    18   Femenino
# 3         LIMA      LIMA                  LIMA    21  Masculino
# 4         LIMA      LIMA  SAN MARTIN DE PORRES    40   Femenino
#
#    PRIMERA_OPCION                         SEGUNDA_OPCION
# 0  Diseño Gráfico  Desarrollo de Sistemas de Información
# 1    Contabilidad                         Administración
# 2  Diseño Gráfico                         Diseño Gráfico
# 3  Administración  Desarrollo de Sistemas de Información
# 4    Contabilidad                         Administración

# %%
data = data.rename(columns={ 'PRIMERA_OPCION':'PRIMERA CARRERA', 'SEGUNDA_OPCION': 'SEGUNDA CARRERA' })

# %%
columns = ['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'EDAD', 'SEXO', 'PRIMERA CARRERA', 'SEGUNDA CARRERA']
datanueva = data[columns]
datanueva
# Out:
#     DEPARTAMENTO PROVINCIA                DISTRITO  EDAD       SEXO  \
# 0         CALLAO    CALLAO                  CALLAO    18  Masculino
# 1           LIMA      LIMA                    LIMA    31  Masculino
# 2           LIMA      LIMA                    LIMA    18   Femenino
# 3           LIMA      LIMA                    LIMA    21  Masculino
# 4           LIMA      LIMA    SAN MARTIN DE PORRES    40   Femenino
# ..           ...       ...                     ...   ...        ...
# 856       CALLAO    CALLAO                  CALLAO    41   Femenino
# 857         LIMA      LIMA                   RIMAC    49   Femenino
# 858       CALLAO    CALLAO                  CALLAO    27   Femenino
# 859         LIMA      LIMA  SAN JUAN DE LURIGANCHO    34  Masculino
# 860       CALLAO    CALLAO                  CALLAO    26        NaN
#
#                            PRIMERA CARRERA  \
# 0                           Diseño Gráfico
# 1                             Contabilidad
# 2                           Diseño Gráfico
# 3                           Administración
# 4                             Contabilidad
# ..                                     ...
# 856                         Administración
# 857                 Secretariado Ejecutivo
# 858                 Secretariado Ejecutivo
# 859  Desarrollo de Sistemas de Información
# 860                 Mecánica de Producción
#
#                            SEGUNDA CARRERA
# 0    Desarrollo de Sistemas de Información
# 1                           Administración
# 2                           Diseño Gráfico
# 3    Desarrollo de Sistemas de Información
# 4                           Administración
# ..                                     ...
# 856                         Diseño Gráfico
# 857                         Administración
# 858                    Diseño Publicitario
# 859                    Diseño Publicitario
# 860                    Mecánica Automotriz
#
# [861 rows x 7 columns]

# %% [markdown]
# <h1>VERIFICANDO SI HAY DATOS NULOS</h1>

# %% [markdown]
# <p>Mostrando la cantidad de datos nulos por columna</p>

# %%
datanueva.isnull().sum()
# Out:
# DEPARTAMENTO        0
# PROVINCIA           0
# DISTRITO            0
# EDAD                0
# SEXO               38
# PRIMERA CARRERA     0
# SEGUNDA CARRERA     0
# dtype: int64

# %% [markdown]
# <p>Mostrando filas con datos nulos</p>

# %%
datanueva[datanueva.isnull().any(axis=1)].head(20)
# Out:
#     DEPARTAMENTO PROVINCIA                    DISTRITO  EDAD SEXO  \
# 117       CALLAO    CALLAO                  VENTANILLA    17  NaN
# 136       CALLAO    CALLAO                  VENTANILLA    18  NaN
# 162       CALLAO    CALLAO                      CALLAO    24  NaN
# 164       CALLAO    CALLAO                      CALLAO    22  NaN
# 210       CALLAO    CALLAO                      CALLAO    20  NaN
# 234       CALLAO    CALLAO                  BELLAVISTA    33  NaN
# 236         LIMA      LIMA                  LOS OLIVOS    17  NaN
# 252         LIMA      LIMA        SAN MARTIN DE PORRES    22  NaN
# 254       CALLAO    CALLAO                    LA PERLA    25  NaN
# 256       CALLAO    CALLAO                      CALLAO    18  NaN
# 314         LIMA      LIMA                       RIMAC    43  NaN
# 325         LIMA      LIMA        SAN MARTIN DE PORRES    18  NaN
# 346       CALLAO    CALLAO                  VENTANILLA    22  NaN
# 368         LIMA      LIMA        SAN MARTIN DE PORRES    19  NaN
# 396       CALLAO    CALLAO                  VENTANILLA    28  NaN
# 412       CALLAO    CALLAO                      CALLAO    17  NaN
# 414         LIMA      LIMA                  SAN MIGUEL    27  NaN
# 450         LIMA      LIMA                  LOS OLIVOS    17  NaN
# 513         LIMA      LIMA                  SAN MIGUEL    18  NaN
# 537       CALLAO    CALLAO  CARMEN DE LA LEGUA REYNOSO    30  NaN
#
#                            PRIMERA CARRERA  \
# 117                    Mecánica Automotriz
# 136                         Diseño Gráfico
# 162                         Administración
# 164                           Contabilidad
# 210                 Mecánica de Producción
# 234                 Secretariado Ejecutivo
# 236                         Diseño Gráfico
# 252                         Administración
# 254                         Diseño Gráfico
# 256                    Diseño Publicitario
# 314                           Contabilidad
# 325                           Contabilidad
# 346                         Diseño Gráfico
# 368                           Contabilidad
# 396                         Administración
# 412  Desarrollo de Sistemas de Información
# 414                         Administración
# 450  Desarrollo de Sistemas de Información
# 513                         Diseño Gráfico
# 537                         Administración
#
#                            SEGUNDA CARRERA
# 117                 Mecánica de Producción
# 136                         Diseño Gráfico
# 162                    Diseño Publicitario
# 164                 Secretariado Ejecutivo
# 210                    Mecánica Automotriz
# 234                         Administración
# 236                    Diseño Publicitario
# 252  Desarrollo de Sistemas de Información
# 254                    Diseño Publicitario
# 256                         Diseño Gráfico
# 314                         Administración
# 325                         Diseño Gráfico
# 346                         Administración
# 368                         Administración
# 396                         Administración
# 412                    Diseño Publicitario
# 414                     Construcción Civil
# 450                           Contabilidad
# 513                     Construcción Civil
# 537                           Contabilidad

# %% [markdown]
# <h2>Eliminando datos que estan nulos</h2>

# %%
datanueva_limpia = datanueva.dropna()

# %%
datanueva_limpia[datanueva_limpia.isnull().any(axis=1)].head(20)

#Como se visualiza ya no hay ningun dato nulo
# Out:
# Empty DataFrame
# Columns: [DEPARTAMENTO, PROVINCIA, DISTRITO, EDAD, SEXO, PRIMERA CARRERA, SEGUNDA CARRERA]
# Index: []

# %%
datanueva_limpia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 823 entries, 0 to 859
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DEPARTAMENTO     823 non-null    object
#  1   PROVINCIA        823 non-null    object
#  2   DISTRITO         823 non-null    object
#  3   EDAD             823 non-null    int64
#  4   SEXO             823 non-null    object
#  5   PRIMERA CARRERA  823 non-null    object
#  6   SEGUNDA CARRERA  823 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 51.4+ KB

# %% [markdown]
# <h1>Guardando datos en un archivo limpio</h1>

# %%
datanueva_limpia.to_csv('../data_limpia/datalimpia.csv', index=False)

# %% [markdown]
# <h1>ANALISIS EXPLORATORIO DE DATOS</h1>

# %% [markdown]
# <p>Utilizando group by podemos agrupar datos lo cual nos permite poder mostrar una cantidad total de la columna o dato que queramos sacar.</p>

# %% [markdown]
# <p>Conoceremos la cantidad segun su sexo de postulantes que han aplicado para la carrera de sistemas</p>

# %%
datanuevalimpia = pd.read_csv("../data_limpia/datalimpia.csv", sep=",")


pit.figure(figsize=(16, 6))

columna1 = 'PRIMERA CARRERA'
columna2 = "SEXO"
carrera_key = "Desarrollo de Sistemas de Información"

datos = datanuevalimpia[datanuevalimpia[columna1].str.contains(carrera_key)].groupby([columna1, columna2]).size().groupby([columna2]).max()

pit.title("Grafico de la cantidad de hombres y mujeres postularon a sistemas")

pit.bar("Mujeres", datos[0])
pit.bar("Hombres", datos[1])

pit.show()

# %%
# Out:
# 83
